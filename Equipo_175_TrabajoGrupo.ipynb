# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo175-rva-a01378921-rrm-a01793108/blob/main/Equipo_175_TrabajoGrupo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 1

# %% [markdown]
# Materia: Ciencia y anallítica de datos
#
# Nombre y matrícula de miembros del equipo 175:
#
# Roberto Vega Alanis (A01378921)
#
# Jhonathan Ricardo Robayo Martínez (A01793108)

# %% [markdown]
# **Introducción**
#
# El conjunto de datos seleccionado es una muestra representativa de un registro de transacciones dentro de la cadena de suministro de una empresa de retail. En una empresa, cadena de suministro es una de las áreas que generalmente cuenta con la mayor cantidad de datos y que, al mismo tiempo, es aquella que irónicamente suele desaprovecharlos más.
#
# Esta misma área engloba las actividades de manufactura y distribución de producto, mismas en las que bien es sabido radican la mayor parte de oportunidades de eficientización.
#
# El conjunto de datos seleccionado, por lo tanto, está destinado a resolver un problema tanto económico, al buscar reducir cotos aumentando la eficiencia de los sistemas de distribución y, por lo tanto, ecológico al buscar brindar el mismo servicio haciendo uso una menor cantidad de recursos.
#
# **Respuestas:**
#
# 1. El nombre que caracteriza el conjunto de datos:
# > DataCoSupplyChainDataset
#
# 2. La organización que lo generó
# > DataCo Global (https://www.crunchbase.com/organization/dataco-77ff)
#
# 3. Incluya un enlace de Internet donde se puedan descargar el base de datos en línea:
# > https://data.mendeley.com/datasets/8gx2fvg2k6/5 (fuente adicional: https://www.kaggle.com/datasets/shashwatwork/dataco-smart-supply-chain-for-big-data-analysis)
#
# 4. Describe el conjunto de datos. ¿Qué datos contiene?
#
# > Contiene información sobre retail, desde la petición del producto hasta su llegada; si el pedido fue cancelado o no; que tipo de membresía de envío tienen los clientes; que medio de pago utilizan; el lugar de entrega, que identifica desde el país hasta algunas de sus regiones; contiene además el valor monetario de los pedios; el beneficio y categoría del pedido, por mencionar algunas variables.
#
# 5. ¿Cuáles son algunas de las preguntas de investigación que podría responder con estos datos? Enumere al menos OCHO (no responda las preguntas).
#
# > Las preguntas de investigación que podemos resolver son varias y dependerán del objetivo que se tenga, pues como ya se mencionó, los datos tienen algunas desagregaciones. Por lo cual, podríamos crear varios modelos generales y luego focalizarlos. Por ejemplo, pasaríamos a estudiar la cancelación de pedidos o preferencias de membresías en general y luego analizaríamos que particularidad existe dentro de los distintos países o medios de pago.
#
# Algunos ejemplos generales son:
#
#    * Probabilidad de cancelación de un pedido.
#    * Predicción de si el envío llegará a tiempo.
#    * Predicción de los días de retraso de la entrega.
#    * Predicción del nivel de ganancias.
#    * Predicción del nivel de ventas.
#    * Predicción del tipo de membresía para futuros o actuales clientes (eligendo la más rentable, se buscaría identificar que clientes que no la tienen para recomendarles).
#    * Recomendación de medios de pago (eligiendo el más rentable, se buscaría identificar que clientes que no tienen este servicio para recomendarles).
#    * Identificar qué productos, países o montos tienen retrasos, para generar estrategias.
#    * Predecir los días de retraso para establecer el tiempo que se demoraría la entrega.
#    * Predecir la probabilidad de compra de productos para realizar abastecimientos.
#    * Generar un sistema de recomendación de productos (pero tal vez sea necesario tener información complementaria).
#
# Es notable que algunas de las preguntas van a generar resultados que luego pueden ser utilizados para responder otras preguntas.
#
# 6. ¿Qué actor (empresa, sector de la sociedad, organismo descentralizado, gobierno, etc.) estaría interesado en las preguntas mencionadas que identificó?
#
# > Las empresas que se interesarían por estas respuestas serían:
#
#  * Retail (Walmart, Soriana, Chedraui)
#  * Cualquier empresa con esquema de venta DTC (Direct To Customer) (PepsiCo)
#  * Tiendas en línea (Mercado Libre, Amazon)
#  * Empresas de paqueterías (UPS, DHL)

# %% [markdown]
# ## Ingesta de datos

# %%
# Librarías
import pandas as pd

# %%
delivery = pd.read_csv("DataCoSupplyChainDataset.csv", sep =",", encoding ='latin1')
delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
delivery.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %% [markdown]
# # Semana 2

# %% [markdown]
# Materia: Ciencia y anallítica de datos
#
# Nombre y matrícula de miembros del equipo 175:
#
# Roberto Vega Alanis (A01378921)
#
# Jhonathan Ricardo Robayo Martínez (A01793108)
#
#
# ---
#
#
#
# Metodología seleccionada: CRISP - DM

# %% [markdown]
# <iframe width="768" height="432" src="https://miro.com/app/live-embed/uXjVPTBfyyE=/?moveToViewport=-2176,-13,2591,1451&embedId=276081334780" frameborder="0" scrolling="no" allowfullscreen></iframe>

# %% [markdown]
# ![My First Board (2).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Link para mejor visualización: https://miro.com/app/board/uXjVPTBfyyE=/?share_link_id=457072612294
